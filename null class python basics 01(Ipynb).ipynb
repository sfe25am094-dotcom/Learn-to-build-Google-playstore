# %%
print("hello world")
# Out:
# hello world

# %%
print(2+4)
# Out:
# 6

# %%
print(5*6)
# Out:
# 30

# %%
l=[1,2,3,4]
print(l)
# Out:
# [1, 2, 3, 4]

# %%
s=["windows","linux","mac"]
print(s)
# Out:
# ['windows', 'linux', 'mac']

# %%
x=[1,"hi",4.01]
x
# Out:
# [1, 'hi', 4.01]

# %%
t=("hi","hello","how are you")
t
# Out:
# ('hi', 'hello', 'how are you')

# %%
t=("hi",4.0)
t
# Out:
# ('hi', 4.0)

# %%
a=4
if a%2==0:
    print(1)
else:
    print(0)
# Out:
# 1

# %%
i=1
while i<5:
    print(i)
    i=i+1
# Out:
# 1
# 2
# 3
# 4

# %%
vegetables=["potato","cabage","onion"]
for x in vegetables:
    print(x)
# Out:
# potato
# cabage
# onion

# %%
def myfunction(a):
    if a%2==0:
        return 1
    else:
        return 0
myfunction(5)
# Out:
# 0

# %%
x=lambda a:a+1
print(x(5))
# Out:
# 6
